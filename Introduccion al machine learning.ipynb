# %% [markdown]
# # Introduccion al machine learning
#
# El __Machine learning__ es un termino que se ha escuchado mucho ultimamente y es correspondiente al area de __ciencias de datos__, me saltare todo lo que corresponde a las ciencias de datos puras hare esta serie de documentos que almacenare en __GitHub__ y en __Amino__, en esta serie pretendo cubrir una introduccion al __Machine Learning__
#
# ## Motivaciones
#
# La mayoria de documentos correspondientes al __Data Science__ En su mayoria estan en ingles y eso puede ser algo inaccesible para ciertas personas, asique quiero acercar esta tecnica a las personas interesadas de habla hispana, ya que la habla inglesa tiene un material muy extenso sobre esta tecnica, lo hare en formato de libro ya que es mas comprensible y a mi me da nostalgia ya que mis primeros acercamientos a la programacion fue en libros espero pueda quedar bastante claro el material cualquier duda o pregunta podra ser resuelta ya sea por mensaje privado en __Amino__ o a mi correo de contacto __jcrispis56@gmail.com__ cualquier copia sin creditos o uso indevido de esta informacion debe ser reportado al correo anterior dado ya que esta sujeto a derechos de autor bajo mi autoria y paso a explicar de que manera autorizo a usar o distribuir esta obra.
#
# __Micro Distribucion: Libre siempre y cuando se preserven datos personales como el correo personal__
# __Citacion: Libre siempre y cuando se diga el autor del material__
# __Reedicion: Libre siempre y cuando se diga el autor del material, y anexo al editor__
# __Macro Distribuicion: siempre y cuando se llegue a un acuerdo con el autor__
# __ESTE DOCUMENTO ES GRATIS SI SE LO VENDEN CONTACTE CON EL AUTOR__
# __La apropiacion indevida sera sancionada monetariamente__
#
# # Preparados Listos YA!
#
# En esta seccion aprenderemos a descargar e instalar anaconda para python 3, debemos seguir el documento paso a paso para que los resultados sean los mismos o muy cercanos al original, todo estara explicado lo mas didacticamente posible con guias de imagenes acompañados por una explicacion muy clara de texto guia
#
# ## Instalacion de anaconda para Python 3
#
# Para instalar __Anaconda__ una libreria hecha por __Anaconda, Inc.__ para almacenar todas las librerias de __Data Science__ para instalarla debemos ir a su pagina oficial.
#
# https://www.anaconda.com/download/
#
#
# Y debemos seguir los siguentes pasos
#
# ![title](img/intro_1/im1.png)
#
# Apretamos el la casilla de abajo correspondiente a la arquitectura de su procesador en mi caso _64-Bit Graphical Installer (537 MB)_ que se corresponde con mi sistema operativo y tener el cuenta la version de __Python 3__ por que es en esta version en la que trabajaremos una vez que se descargue le damos doble click y se nos abrira el instalador leemos el acuerdo de licencia y le damos siguiente, los pasos siguientes seran bastante normales pero hay uno que debemos hacer para que todo funcione correctamente y es la siguiente
#
# ![title](img/intro_1/im2.png)
#
# Esto añadira el comando __conda__ a nuestra consola y hara que el programa funcione correctamente y luego instalamos el proceso llevara de 5 a 30 minutos dependiendo del ordenador
#
# podemos crear entornos con anaconda de 2 formas ahora repasaremos aquellas 2 formas
#
# ## Anaconda Navigator
#
# ![title](img/intro_1/im3.png)
#
# Para instalar una libreria con conda navigator solo debemos ir a la carpeta de __Anaconda__ en el inicio e iniciar el __Anaconda Navigator__ y se nos abrira una ventana como esta
#
# ![title](img/intro_1/im4.png)
#
# Aqui tendremos varias opciones nos iremos directamente a esta
#
# ![title](img/intro_1/im5.png)
#
# Y aqui en la parte inferior buscaremos el boton Create
#
# ![title](img/intro_1/im6.png)
#
# Y se nos abrira la ventana de creacion de entornos de trabajo y le pondremos de nombre *Sklearn* o Cualquiera
#
# ![title](img/intro_1/im7.png)
#
# Y le das a create
#
# ## CMD
#
# La forma 2 es por el cmd, abrimos una nueva ventana de cmd *Windows+r cmd* o ejecutar y *cmd* y una vez alli escribimos el siguiente comando
#
# ![title](img/intro_1/im8.png)
#
# ___conda create --name sklearn python=3.6___
#
# le damos a intro y resolvera la transaccion y le damos __(Y)__ a todo
#
# # Instalacion de paquetes
#
# Tenemos 4 formas para instalar paquetes y todas funcionan vamos a repasarlas
#
# ## Anaconda Navigator
#
# Abrimos anaconda navigator, Vamos a enviroments
#
# ![title](img/intro_1/im5.png)
#
# Doble click en nuestro entorno para activar, debemos asegurarnos que se ponga una columna verde es su izquierda
#
# ![title](img/intro_1/im9.png)
#
# buscamos esta caja y la ponemos de installed a not installed y para el ejemplo instalaremos pandas que es una libreria que usaremos
#
# ![title](img/intro_1/im10.png)
#
# y por ultimo le damos doble click en el cuadro blanco de la izquierda a pandas y apretamos apply
#
# ![title](img/intro_1/im11.png)
#
# ## CMD
#
# Para instalar por el cmd abrimos una ventana de comandos nueva *Windows+r cmd* o ejecutar cmd y activamos nuestro entorno escribiendo ___activate sklearn___
#
#
# ![title](img/intro_1/im12.png)
#
# esperamos a que se active y nos aseguramos que diga el nombre de nuestro entorno en la izquierda
#
# ![title](img/intro_1/im13.png)
#
# y para instalar una libreria devemos ejecutar el comando ___conda install (nombre de la libreria)___ en este caso el comando sera ___conda install pandas__
#
# ![title](img/intro_1/im14.png)
#
# y le damos a __(Y)__
#
# # PIP
#
# Para instalar por el cmd abrimos una ventana de comandos nueva *Windows+r cmd* o ejecutar cmd y activamos nuestro entorno escribiendo ___activate sklearn___
#
#
# ![title](img/intro_1/im12.png)
#
# esperamos a que se active y nos aseguramos que diga el nombre de nuestro entorno en la izquierda
#
# ![title](img/intro_1/im13.png)
#
# y luego escribimos el comando ___pip install (nombre de la libreria)___ en este caso el comando sera ___pip install pandas___ y ejecutamos no nos pedira ni una confirmacion
#
# # Jupyter Notebook (IPython notebook)
#
# Abrimos jupyter creamos un nuevo notebook en new > python 3
#
# ![title](img/intro_1/im15.png)
#
# escribimos en la primera celda ___!pip install(nombre de la libreria)___ en este caso ___!pip install pandas___
#
# # Estamos a un paso de comenzar :)
#
# Pero antes debemos tener un conocimiento base en python asique recomiendo antes de proseguir tomar el curso de code academy de python en este link
#
# https://www.codecademy.com/catalog/language/python
#
# programing in python y si no tienen un buen nivel de ingles recomiendo el siguiente video curso de codigo facilito
#
# https://codigofacilito.com/cursos/python-profesional
#
# Luego de completar este __Crash Course__ podemos proseguir con el curso
